# %% [markdown]
# # Aisera-Programming-Assignment-Solution
# __Author__: Tianye Lin
# __Date__: 10/20/2018

# %% [markdown]
# ## Import Packages

# %%
import statistics
import re
import ijson

# %% [markdown]
# ## Define Query Functions

# %%
def print_userCount_year(json_list):
    year_count = {}
    for single_json in json_list:
        year = re.search(r'\d+', single_json["registered"]).group()
        if year in year_count:
            year_count[year] += 1
        else:
            year_count[year] = 1
    print('Number of users registered in each year:')
    for key in sorted(year_count):
        print("%s: %s" % (key, year_count[key]))

# %%
def print_median_friendCount(json_list):
    friend_count = []
    for single_json in json_list:
        friend_count.append(len(single_json["friends"]))
    print('Median for number of friends:')
    print(statistics.median(friend_count))

# %%
def print_median_age(json_list):
    age_list = []
    for single_json in json_list:
        age_list.append(single_json["age"])
    print('Median age for users:')
    print(statistics.median(age_list))

# %%
def print_mean_balance(json_list):
    balance_list = []
    for single_json in json_list:
        balance_list.append(float(re.sub(r'[^\d.]', '', single_json["balance"])))
    print('Mean balance amount:')
    print('${:,.2f}'.format(statistics.mean(balance_list)))

# %%
def print_mean_activeFemaleUnreadCount(json_list):
    AFUC_list = []
    for single_json in json_list:
        if single_json["isActive"] != True or single_json["gender"] == "male":
            continue
        AFUC_list.append(int(re.search(r'\d+', single_json["greeting"]).group()))
    print('Mean for number of unread messages for active females:')
    print(statistics.mean(AFUC_list))

# %% [markdown]
# ## Define JSON Sreaming Parsing Function

# %%
def iterate_jsonfile(file, json_list, count):
    curr_json = {}
    curr_key = ''
    curr_friendName = {}
    canPrint = False
    with open(file, 'r') as f:
        for prefix, event, value in ijson.parse(f):
            if count > 0 and count%1000 == 0 and canPrint:
                print('Record '+str(count-999)+'-'+str(count)+':')
                print()
                print_userCount_year(json_list)
                print_median_friendCount(json_list)
                print_median_age(json_list)
                print_mean_balance(json_list)
                print_mean_activeFemaleUnreadCount(json_list)
                print()
                json_list = []
                canPrint = False
            if (prefix, event) == ('item', 'end_map'): 
                json_list.append(curr_json)
                count+=1
                canPrint = True
                curr_json = {}
            elif (prefix, event) == ('item', 'map_key') and value != 'friends':
                curr_key = value
            elif prefix.endswith('.' + curr_key) and curr_key != 'friends':
                curr_json[curr_key] = value
            elif (prefix, event) == ('item', 'map_key') and value == 'friends':
                curr_key = value
                curr_json[curr_key] = []
            elif prefix.endswith('.friends.item.name'):
                curr_friendName['name'] = value
                curr_json[curr_key].append(curr_friendName)
                curr_friendName = {}
                
    return json_list, count

# %% [markdown]
# ## Run the Tasks

# %%
json_list, count = iterate_jsonfile('./data/users-1.json', [], 0)
json_list, count = iterate_jsonfile('./data/users-2.json', json_list, count)
# Out:
# Record 1-1000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 176
# 2014: 169
# 2015: 171
# 2016: 170
# 2017: 151
# 2018: 14
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,101.75
# Mean for number of unread messages for active females:
# 47.88340807174888
#
# Record 1001-2000:
#
# Number of users registered in each year:
# 2012: 173
# 2013: 180
# 2014: 139
# 2015: 152
# 2016: 173
# 2017: 163
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,276.90
# Mean for number of unread messages for active females:
# 49.66101694915254
#
# Record 2001-3000:
#
# Number of users registered in each year:
# 2012: 165
# 2013: 160
# 2014: 167
# 2015: 157
# 2016: 167
# 2017: 159
# 2018: 25
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,210.21
# Mean for number of unread messages for active females:
# 51.67078189300412
#
# Record 3001-4000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 166
# 2014: 152
# 2015: 163
# 2016: 166
# 2017: 162
# 2018: 25
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,199.25
# Mean for number of unread messages for active females:
# 47.74476987447699
#
# Record 4001-5000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 185
# 2014: 153
# 2015: 163
# 2016: 154
# 2017: 155
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,340.82
# Mean for number of unread messages for active females:
# 48.962406015037594
#
# Record 5001-6000:
#
# Number of users registered in each year:
# 2012: 162
# 2013: 168
# 2014: 152
# 2015: 173
# 2016: 150
# 2017: 176
# 2018: 19
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,129.95
# Mean for number of unread messages for active females:
# 50.788844621513945
#
# Record 6001-7000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 159
# 2014: 164
# 2015: 176
# 2016: 172
# 2017: 144
# 2018: 28
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,189.31
# Mean for number of unread messages for active females:
# 50.51709401709402
#
# Record 7001-8000:
#
# Number of users registered in each year:
# 2012: 161
# 2013: 160
# 2014: 154
# 2015: 160
# 2016: 167
# 2017: 170
# 2018: 28
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,256.61
# Mean for number of unread messages for active females:
# 51.852589641434264
#
# Record 8001-9000:
#
# Number of users registered in each year:
# 2012: 162
# 2013: 171
# 2014: 173
# 2015: 144
# 2016: 163
# 2017: 164
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,223.58
# Mean for number of unread messages for active females:
# 47.37154150197628
#
# Record 9001-10000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 155
# 2014: 143
# 2015: 159
# 2016: 175
# 2017: 177
# 2018: 21
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,316.24
# Mean for number of unread messages for active females:
# 47.02836879432624
#
# Record 10001-11000:
#
# Number of users registered in each year:
# 2012: 180
# 2013: 157
# 2014: 163
# 2015: 146
# 2016: 178
# 2017: 145
# 2018: 31
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,208.33
# Mean for number of unread messages for active females:
# 53.484848484848484
#
# Record 11001-12000:
#
# Number of users registered in each year:
# 2012: 182
# 2013: 142
# 2014: 167
# 2015: 162
# 2016: 158
# 2017: 171
# 2018: 18
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,196.65
# Mean for number of unread messages for active females:
# 50.97674418604651
#
# Record 12001-13000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 168
# 2014: 167
# 2015: 167
# 2016: 150
# 2017: 162
# 2018: 29
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,239.41
# Mean for number of unread messages for active females:
# 49.27125506072875
#
# Record 13001-14000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 158
# 2014: 161
# 2015: 140
# 2016: 179
# 2017: 174
# 2018: 22
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,276.92
# Mean for number of unread messages for active females:
# 52.44444444444444
#
# Record 14001-15000:
#
# Number of users registered in each year:
# 2012: 172
# 2013: 168
# 2014: 169
# 2015: 139
# 2016: 159
# 2017: 163
# 2018: 30
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,251.84
# Mean for number of unread messages for active females:
# 49.59765625
#
# Record 15001-16000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 154
# 2014: 150
# 2015: 161
# 2016: 175
# 2017: 178
# 2018: 16
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,282.22
# Mean for number of unread messages for active females:
# 50.132616487455195
#
# Record 16001-17000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 158
# 2014: 181
# 2015: 154
# 2016: 146
# 2017: 167
# 2018: 24
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,203.54
# Mean for number of unread messages for active females:
# 48.17063492063492
#
# Record 17001-18000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 150
# 2014: 175
# 2015: 165
# 2016: 164
# 2017: 158
# 2018: 18
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,418.91
# Mean for number of unread messages for active females:
# 54.71848739495798
#
# Record 18001-19000:
#
# Number of users registered in each year:
# 2012: 156
# 2013: 150
# 2014: 146
# 2015: 171
# 2016: 175
# 2017: 177
# 2018: 25
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,265.51
# Mean for number of unread messages for active females:
# 48.6058091286307
#
# Record 19001-20000:
#
# Number of users registered in each year:
# 2012: 159
# 2013: 170
# 2014: 164
# 2015: 150
# 2016: 167
# 2017: 162
# 2018: 28
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,423.65
# Mean for number of unread messages for active females:
# 49.551094890510946
#
# Record 20001-21000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 158
# 2014: 154
# 2015: 165
# 2016: 140
# 2017: 183
# 2018: 30
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,178.33
# Mean for number of unread messages for active females:
# 50.55696202531646
#
# Record 21001-22000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 170
# 2014: 175
# 2015: 170
# 2016: 151
# 2017: 158
# 2018: 19
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,162.58
# Mean for number of unread messages for active females:
# 50.02298850574713
#
# Record 22001-23000:
#
# Number of users registered in each year:
# 2012: 172
# 2013: 153
# 2014: 183
# 2015: 171
# 2016: 146
# 2017: 155
# 2018: 20
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,258.37
# Mean for number of unread messages for active females:
# 47.987755102040815
#
# Record 23001-24000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 164
# 2014: 161
# 2015: 164
# 2016: 150
# 2017: 175
# 2018: 16
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,348.19
# Mean for number of unread messages for active females:
# 50.21343873517787
#
# Record 24001-25000:
#
# Number of users registered in each year:
# 2012: 156
# 2013: 178
# 2014: 165
# 2015: 146
# 2016: 165
# 2017: 159
# 2018: 31
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,257.49
# Mean for number of unread messages for active females:
# 50.067796610169495
#
# Record 25001-26000:
#
# Number of users registered in each year:
# 2012: 148
# 2013: 166
# 2014: 171
# 2015: 160
# 2016: 177
# 2017: 159
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,227.76
# Mean for number of unread messages for active females:
# 50.8860294117647
#
# Record 26001-27000:
#
# Number of users registered in each year:
# 2012: 176
# 2013: 172
# 2014: 165
# 2015: 159
# 2016: 146
# 2017: 162
# 2018: 20
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,137.52
# Mean for number of unread messages for active females:
# 52.477832512315274
#
# Record 27001-28000:
#
# Number of users registered in each year:
# 2012: 154
# 2013: 164
# 2014: 160
# 2015: 161
# 2016: 173
# 2017: 162
# 2018: 26
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,262.80
# Mean for number of unread messages for active females:
# 51.86036036036036
# Record 28001-29000:
#
# Number of users registered in each year:
# 2012: 162
# 2013: 172
# 2014: 181
# 2015: 167
# 2016: 150
# 2017: 146
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,236.02
# Mean for number of unread messages for active females:
# 48.60076045627376
#
# Record 29001-30000:
#
# Number of users registered in each year:
# 2012: 190
# 2013: 176
# 2014: 150
# 2015: 171
# 2016: 162
# 2017: 134
# 2018: 17
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,223.73
# Mean for number of unread messages for active females:
# 49.118852459016395
#
# Record 30001-31000:
#
# Number of users registered in each year:
# 2012: 153
# 2013: 173
# 2014: 153
# 2015: 175
# 2016: 165
# 2017: 155
# 2018: 26
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,072.37
# Mean for number of unread messages for active females:
# 50.85098039215686
#
# Record 31001-32000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 155
# 2014: 168
# 2015: 159
# 2016: 169
# 2017: 153
# 2018: 29
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,324.06
# Mean for number of unread messages for active females:
# 50.94736842105263
#
# Record 32001-33000:
#
# Number of users registered in each year:
# 2012: 172
# 2013: 161
# 2014: 145
# 2015: 170
# 2016: 182
# 2017: 143
# 2018: 27
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,259.17
# Mean for number of unread messages for active females:
# 48.50806451612903
#
# Record 33001-34000:
#
# Number of users registered in each year:
# 2012: 162
# 2013: 153
# 2014: 168
# 2015: 168
# 2016: 172
# 2017: 158
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,201.55
# Mean for number of unread messages for active females:
# 49.83529411764706
#
# Record 34001-35000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 164
# 2014: 157
# 2015: 155
# 2016: 159
# 2017: 170
# 2018: 27
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,219.81
# Mean for number of unread messages for active females:
# 46.76987447698745
#
# Record 35001-36000:
#
# Number of users registered in each year:
# 2012: 161
# 2013: 171
# 2014: 163
# 2015: 132
# 2016: 155
# 2017: 189
# 2018: 29
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,176.61
# Mean for number of unread messages for active females:
# 51.47659574468085
#
# Record 36001-37000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 164
# 2014: 165
# 2015: 164
# 2016: 157
# 2017: 164
# 2018: 29
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,238.09
# Mean for number of unread messages for active females:
# 48.48347107438016
#
# Record 37001-38000:
#
# Number of users registered in each year:
# 2012: 147
# 2013: 142
# 2014: 162
# 2015: 181
# 2016: 181
# 2017: 166
# 2018: 21
# Median for number of friends:
# 6.0
# Median age for users:
# 34.5
# Mean balance amount:
# $5,244.12
# Mean for number of unread messages for active females:
# 48.929515418502206
#
# Record 38001-39000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 146
# 2014: 170
# 2015: 163
# 2016: 176
# 2017: 167
# 2018: 29
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,154.28
# Mean for number of unread messages for active females:
# 51.890756302521005
#
# Record 39001-40000:
#
# Number of users registered in each year:
# 2012: 169
# 2013: 159
# 2014: 155
# 2015: 154
# 2016: 192
# 2017: 144
# 2018: 27
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,136.52
# Mean for number of unread messages for active females:
# 50.99159663865546
#
# Record 40001-41000:
#
# Number of users registered in each year:
# 2012: 180
# 2013: 138
# 2014: 138
# 2015: 179
# 2016: 173
# 2017: 172
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,263.56
# Mean for number of unread messages for active females:
# 46.9789029535865
#
# Record 41001-42000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 147
# 2014: 155
# 2015: 155
# 2016: 153
# 2017: 197
# 2018: 27
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,285.97
# Mean for number of unread messages for active females:
# 49.82857142857143
#
# Record 42001-43000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 166
# 2014: 179
# 2015: 141
# 2016: 159
# 2017: 166
# 2018: 22
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,190.31
# Mean for number of unread messages for active females:
# 51.04347826086956
#
# Record 43001-44000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 174
# 2014: 176
# 2015: 148
# 2016: 150
# 2017: 154
# 2018: 30
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,298.12
# Mean for number of unread messages for active females:
# 50.933035714285715
#
# Record 44001-45000:
#
# Number of users registered in each year:
# 2012: 143
# 2013: 147
# 2014: 181
# 2015: 165
# 2016: 161
# 2017: 185
# 2018: 18
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,286.45
# Mean for number of unread messages for active females:
# 49.613382899628256
#
# Record 45001-46000:
#
# Number of users registered in each year:
# 2012: 180
# 2013: 158
# 2014: 177
# 2015: 156
# 2016: 168
# 2017: 139
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,069.67
# Mean for number of unread messages for active females:
# 46.66129032258065
#
# Record 46001-47000:
#
# Number of users registered in each year:
# 2012: 176
# 2013: 170
# 2014: 167
# 2015: 155
# 2016: 155
# 2017: 157
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,319.61
# Mean for number of unread messages for active females:
# 51.476190476190474
#
# Record 47001-48000:
#
# Number of users registered in each year:
# 2012: 176
# 2013: 156
# 2014: 168
# 2015: 164
# 2016: 160
# 2017: 159
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,141.82
# Mean for number of unread messages for active females:
# 51.31063829787234
#
# Record 48001-49000:
#
# Number of users registered in each year:
# 2012: 146
# 2013: 158
# 2014: 181
# 2015: 167
# 2016: 179
# 2017: 151
# 2018: 18
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,186.08
# Mean for number of unread messages for active females:
# 49.29083665338646
#
# Record 49001-50000:
#
# Number of users registered in each year:
# 2012: 156
# 2013: 178
# 2014: 144
# 2015: 164
# 2016: 167
# 2017: 173
# 2018: 18
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,230.73
# Mean for number of unread messages for active females:
# 49.857142857142854
#
# Record 50001-51000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 156
# 2014: 174
# 2015: 158
# 2016: 172
# 2017: 160
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,206.39
# Mean for number of unread messages for active females:
# 48.890625
#
# Record 51001-52000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 158
# 2014: 167
# 2015: 178
# 2016: 158
# 2017: 167
# 2018: 23
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,270.71
# Mean for number of unread messages for active females:
# 50.02214022140221
#
# Record 52001-53000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 142
# 2014: 166
# 2015: 157
# 2016: 186
# 2017: 153
# 2018: 26
# Median for number of friends:
# 5.5
# Median age for users:
# 35.0
# Mean balance amount:
# $5,182.74
# Mean for number of unread messages for active females:
# 50.69635627530364
#
# Record 53001-54000:
#
# Number of users registered in each year:
# 2012: 159
# 2013: 164
# 2014: 165
# 2015: 146
# 2016: 196
# 2017: 153
# 2018: 17
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,077.05
# Mean for number of unread messages for active females:
# 48.97863247863248
#
# Record 54001-55000:
#
# Number of users registered in each year:
# 2012: 134
# 2013: 161
# 2014: 176
# 2015: 175
# 2016: 170
# 2017: 164
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,341.81
# Mean for number of unread messages for active females:
# 47.2421875
#
# Record 55001-56000:
#
# Number of users registered in each year:
# 2012: 135
# 2013: 154
# 2014: 166
# 2015: 178
# 2016: 175
# 2017: 162
# 2018: 30
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,321.78
# Mean for number of unread messages for active females:
# 52.054621848739494
# Record 56001-57000:
#
# Number of users registered in each year:
# 2012: 151
# 2013: 140
# 2014: 168
# 2015: 179
# 2016: 166
# 2017: 173
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,209.67
# Mean for number of unread messages for active females:
# 48.408396946564885
#
# Record 57001-58000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 151
# 2014: 130
# 2015: 198
# 2016: 164
# 2017: 162
# 2018: 28
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,191.17
# Mean for number of unread messages for active females:
# 48.85140562248996
#
# Record 58001-59000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 172
# 2014: 157
# 2015: 152
# 2016: 177
# 2017: 153
# 2018: 23
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,271.67
# Mean for number of unread messages for active females:
# 47.1025641025641
#
# Record 59001-60000:
#
# Number of users registered in each year:
# 2012: 161
# 2013: 171
# 2014: 161
# 2015: 176
# 2016: 156
# 2017: 156
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,242.98
# Mean for number of unread messages for active females:
# 50.92887029288703
#
# Record 60001-61000:
#
# Number of users registered in each year:
# 2012: 172
# 2013: 178
# 2014: 148
# 2015: 154
# 2016: 155
# 2017: 170
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,229.02
# Mean for number of unread messages for active females:
# 48.43290043290043
#
# Record 61001-62000:
#
# Number of users registered in each year:
# 2012: 158
# 2013: 161
# 2014: 166
# 2015: 187
# 2016: 154
# 2017: 147
# 2018: 27
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,235.80
# Mean for number of unread messages for active females:
# 49.43913043478261
#
# Record 62001-63000:
#
# Number of users registered in each year:
# 2012: 160
# 2013: 165
# 2014: 132
# 2015: 176
# 2016: 164
# 2017: 179
# 2018: 24
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,383.30
# Mean for number of unread messages for active females:
# 50.699588477366255
#
# Record 63001-64000:
#
# Number of users registered in each year:
# 2012: 174
# 2013: 159
# 2014: 164
# 2015: 185
# 2016: 159
# 2017: 140
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 34.5
# Mean balance amount:
# $5,101.37
# Mean for number of unread messages for active females:
# 48.192
#
# Record 64001-65000:
#
# Number of users registered in each year:
# 2012: 184
# 2013: 159
# 2014: 169
# 2015: 158
# 2016: 167
# 2017: 146
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,268.42
# Mean for number of unread messages for active females:
# 50.702127659574465
#
# Record 65001-66000:
#
# Number of users registered in each year:
# 2012: 153
# 2013: 159
# 2014: 159
# 2015: 178
# 2016: 162
# 2017: 167
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,328.16
# Mean for number of unread messages for active females:
# 48.49818181818182
#
# Record 66001-67000:
#
# Number of users registered in each year:
# 2012: 165
# 2013: 176
# 2014: 169
# 2015: 171
# 2016: 153
# 2017: 143
# 2018: 23
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,142.83
# Mean for number of unread messages for active females:
# 48.10526315789474
#
# Record 67001-68000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 168
# 2014: 146
# 2015: 158
# 2016: 177
# 2017: 165
# 2018: 20
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,312.45
# Mean for number of unread messages for active females:
# 46.349809885931556
#
# Record 68001-69000:
#
# Number of users registered in each year:
# 2012: 155
# 2013: 147
# 2014: 192
# 2015: 168
# 2016: 169
# 2017: 156
# 2018: 13
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,242.93
# Mean for number of unread messages for active females:
# 51.62256809338521
#
# Record 69001-70000:
#
# Number of users registered in each year:
# 2012: 181
# 2013: 165
# 2014: 157
# 2015: 150
# 2016: 153
# 2017: 170
# 2018: 24
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,204.33
# Mean for number of unread messages for active females:
# 52.37547892720306
#
# Record 70001-71000:
#
# Number of users registered in each year:
# 2012: 156
# 2013: 184
# 2014: 161
# 2015: 148
# 2016: 162
# 2017: 174
# 2018: 15
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,305.80
# Mean for number of unread messages for active females:
# 50.22222222222222
#
# Record 71001-72000:
#
# Number of users registered in each year:
# 2012: 181
# 2013: 159
# 2014: 166
# 2015: 156
# 2016: 131
# 2017: 173
# 2018: 34
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,196.26
# Mean for number of unread messages for active females:
# 50.42570281124498
#
# Record 72001-73000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 146
# 2014: 160
# 2015: 151
# 2016: 166
# 2017: 206
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,260.20
# Mean for number of unread messages for active females:
# 48.71551724137931
#
# Record 73001-74000:
#
# Number of users registered in each year:
# 2012: 165
# 2013: 163
# 2014: 172
# 2015: 172
# 2016: 153
# 2017: 147
# 2018: 28
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,376.14
# Mean for number of unread messages for active females:
# 51.149797570850204
#
# Record 74001-75000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 158
# 2014: 156
# 2015: 161
# 2016: 157
# 2017: 172
# 2018: 28
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,182.00
# Mean for number of unread messages for active females:
# 48.38132295719844
#
# Record 75001-76000:
#
# Number of users registered in each year:
# 2012: 159
# 2013: 183
# 2014: 147
# 2015: 167
# 2016: 148
# 2017: 182
# 2018: 14
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,242.15
# Mean for number of unread messages for active females:
# 47.32234432234432
#
# Record 76001-77000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 155
# 2014: 195
# 2015: 158
# 2016: 154
# 2017: 167
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,265.03
# Mean for number of unread messages for active females:
# 52.159183673469386
#
# Record 77001-78000:
#
# Number of users registered in each year:
# 2012: 153
# 2013: 191
# 2014: 175
# 2015: 151
# 2016: 153
# 2017: 156
# 2018: 21
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,158.05
# Mean for number of unread messages for active females:
# 51.17596566523605
#
# Record 78001-79000:
#
# Number of users registered in each year:
# 2012: 144
# 2013: 151
# 2014: 176
# 2015: 169
# 2016: 152
# 2017: 178
# 2018: 30
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,210.14
# Mean for number of unread messages for active females:
# 51.125
#
# Record 79001-80000:
#
# Number of users registered in each year:
# 2012: 175
# 2013: 171
# 2014: 162
# 2015: 151
# 2016: 173
# 2017: 146
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,310.83
# Mean for number of unread messages for active females:
# 52.50409836065574
#
# Record 80001-81000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 159
# 2014: 167
# 2015: 167
# 2016: 189
# 2017: 146
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,269.53
# Mean for number of unread messages for active females:
# 51.51091703056768
#
# Record 81001-82000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 176
# 2014: 155
# 2015: 163
# 2016: 152
# 2017: 165
# 2018: 40
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,329.33
# Mean for number of unread messages for active females:
# 51.407725321888414
#
# Record 82001-83000:
#
# Number of users registered in each year:
# 2012: 174
# 2013: 161
# 2014: 166
# 2015: 165
# 2016: 162
# 2017: 161
# 2018: 11
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,171.16
# Mean for number of unread messages for active females:
# 52.924107142857146
#
# Record 83001-84000:
#
# Number of users registered in each year:
# 2012: 161
# 2013: 168
# 2014: 152
# 2015: 153
# 2016: 179
# 2017: 161
# 2018: 26
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,214.21
# Mean for number of unread messages for active females:
# 50.42338709677419
# Record 84001-85000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 188
# 2014: 144
# 2015: 154
# 2016: 163
# 2017: 155
# 2018: 28
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,112.47
# Mean for number of unread messages for active females:
# 50.79746835443038
#
# Record 85001-86000:
#
# Number of users registered in each year:
# 2012: 154
# 2013: 154
# 2014: 177
# 2015: 179
# 2016: 141
# 2017: 172
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,254.36
# Mean for number of unread messages for active females:
# 45.75092936802974
#
# Record 86001-87000:
#
# Number of users registered in each year:
# 2012: 176
# 2013: 155
# 2014: 152
# 2015: 172
# 2016: 155
# 2017: 172
# 2018: 18
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,207.29
# Mean for number of unread messages for active females:
# 48.31349206349206
#
# Record 87001-88000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 165
# 2014: 160
# 2015: 173
# 2016: 169
# 2017: 156
# 2018: 28
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,452.82
# Mean for number of unread messages for active females:
# 50.27838827838828
#
# Record 88001-89000:
#
# Number of users registered in each year:
# 2012: 160
# 2013: 154
# 2014: 165
# 2015: 143
# 2016: 189
# 2017: 163
# 2018: 26
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,227.42
# Mean for number of unread messages for active females:
# 53.59398496240601
#
# Record 89001-90000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 182
# 2014: 156
# 2015: 148
# 2016: 173
# 2017: 149
# 2018: 26
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,366.05
# Mean for number of unread messages for active females:
# 51.89837398373984
#
# Record 90001-91000:
#
# Number of users registered in each year:
# 2012: 173
# 2013: 146
# 2014: 175
# 2015: 160
# 2016: 156
# 2017: 159
# 2018: 31
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,317.80
# Mean for number of unread messages for active females:
# 50.41880341880342
#
# Record 91001-92000:
#
# Number of users registered in each year:
# 2012: 162
# 2013: 165
# 2014: 178
# 2015: 173
# 2016: 148
# 2017: 145
# 2018: 29
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,398.45
# Mean for number of unread messages for active females:
# 49.76923076923077
#
# Record 92001-93000:
#
# Number of users registered in each year:
# 2012: 143
# 2013: 169
# 2014: 152
# 2015: 176
# 2016: 190
# 2017: 153
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,139.45
# Mean for number of unread messages for active females:
# 49.28861788617886
#
# Record 93001-94000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 172
# 2014: 143
# 2015: 180
# 2016: 165
# 2017: 172
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,338.69
# Mean for number of unread messages for active females:
# 50.346666666666664
#
# Record 94001-95000:
#
# Number of users registered in each year:
# 2012: 150
# 2013: 154
# 2014: 165
# 2015: 164
# 2016: 163
# 2017: 184
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,369.39
# Mean for number of unread messages for active females:
# 50.80232558139535
#
# Record 95001-96000:
#
# Number of users registered in each year:
# 2012: 172
# 2013: 151
# 2014: 158
# 2015: 165
# 2016: 172
# 2017: 174
# 2018: 8
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,272.74
# Mean for number of unread messages for active females:
# 49.392712550607285
#
# Record 96001-97000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 152
# 2014: 191
# 2015: 155
# 2016: 150
# 2017: 162
# 2018: 24
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,247.61
# Mean for number of unread messages for active females:
# 51.756554307116104
#
# Record 97001-98000:
#
# Number of users registered in each year:
# 2012: 163
# 2013: 164
# 2014: 189
# 2015: 157
# 2016: 153
# 2017: 152
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,169.33
# Mean for number of unread messages for active females:
# 49.267489711934154
#
# Record 98001-99000:
#
# Number of users registered in each year:
# 2012: 169
# 2013: 159
# 2014: 165
# 2015: 153
# 2016: 175
# 2017: 151
# 2018: 28
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,166.34
# Mean for number of unread messages for active females:
# 49.929961089494164
#
# Record 99001-100000:
#
# Number of users registered in each year:
# 2012: 155
# 2013: 179
# 2014: 157
# 2015: 167
# 2016: 164
# 2017: 156
# 2018: 22
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,239.57
# Mean for number of unread messages for active females:
# 49.87109375
#
# Record 100001-101000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 186
# 2014: 140
# 2015: 158
# 2016: 153
# 2017: 172
# 2018: 24
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,399.68
# Mean for number of unread messages for active females:
# 50.53252032520325
#
# Record 101001-102000:
#
# Number of users registered in each year:
# 2012: 194
# 2013: 179
# 2014: 146
# 2015: 152
# 2016: 142
# 2017: 170
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,315.33
# Mean for number of unread messages for active females:
# 49.20909090909091
#
# Record 102001-103000:
#
# Number of users registered in each year:
# 2012: 153
# 2013: 169
# 2014: 145
# 2015: 185
# 2016: 172
# 2017: 159
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,095.92
# Mean for number of unread messages for active females:
# 48.73764258555133
#
# Record 103001-104000:
#
# Number of users registered in each year:
# 2012: 178
# 2013: 162
# 2014: 171
# 2015: 171
# 2016: 139
# 2017: 153
# 2018: 26
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,358.90
# Mean for number of unread messages for active females:
# 49.472527472527474
#
# Record 104001-105000:
#
# Number of users registered in each year:
# 2012: 179
# 2013: 173
# 2014: 141
# 2015: 182
# 2016: 157
# 2017: 141
# 2018: 27
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,341.42
# Mean for number of unread messages for active females:
# 48.82572614107884
#
# Record 105001-106000:
#
# Number of users registered in each year:
# 2012: 146
# 2013: 171
# 2014: 165
# 2015: 162
# 2016: 150
# 2017: 181
# 2018: 25
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,278.77
# Mean for number of unread messages for active females:
# 47.98780487804878
#
# Record 106001-107000:
#
# Number of users registered in each year:
# 2012: 144
# 2013: 165
# 2014: 183
# 2015: 162
# 2016: 165
# 2017: 165
# 2018: 16
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,335.17
# Mean for number of unread messages for active females:
# 48.24166666666667
#
# Record 107001-108000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 151
# 2014: 169
# 2015: 167
# 2016: 163
# 2017: 175
# 2018: 18
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,314.80
# Mean for number of unread messages for active females:
# 49.72064777327935
#
# Record 108001-109000:
#
# Number of users registered in each year:
# 2012: 189
# 2013: 166
# 2014: 141
# 2015: 164
# 2016: 149
# 2017: 167
# 2018: 24
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,270.94
# Mean for number of unread messages for active females:
# 49.98039215686274
#
# Record 109001-110000:
#
# Number of users registered in each year:
# 2012: 155
# 2013: 165
# 2014: 156
# 2015: 167
# 2016: 164
# 2017: 172
# 2018: 21
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,289.52
# Mean for number of unread messages for active females:
# 50.0625
#
# Record 110001-111000:
#
# Number of users registered in each year:
# 2012: 148
# 2013: 167
# 2014: 168
# 2015: 157
# 2016: 172
# 2017: 165
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,101.13
# Mean for number of unread messages for active females:
# 50.318385650224215
#
# Record 111001-112000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 157
# 2014: 168
# 2015: 167
# 2016: 168
# 2017: 150
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,258.05
# Mean for number of unread messages for active females:
# 48.129411764705885
# Record 112001-113000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 137
# 2014: 150
# 2015: 163
# 2016: 179
# 2017: 188
# 2018: 34
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,404.27
# Mean for number of unread messages for active females:
# 47.60698689956332
#
# Record 113001-114000:
#
# Number of users registered in each year:
# 2012: 171
# 2013: 156
# 2014: 156
# 2015: 146
# 2016: 170
# 2017: 169
# 2018: 32
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,266.57
# Mean for number of unread messages for active females:
# 50.52651515151515
#
# Record 114001-115000:
#
# Number of users registered in each year:
# 2012: 145
# 2013: 174
# 2014: 180
# 2015: 168
# 2016: 149
# 2017: 159
# 2018: 25
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,245.87
# Mean for number of unread messages for active females:
# 48.11969111969112
#
# Record 115001-116000:
#
# Number of users registered in each year:
# 2012: 165
# 2013: 164
# 2014: 166
# 2015: 172
# 2016: 146
# 2017: 154
# 2018: 33
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,223.51
# Mean for number of unread messages for active females:
# 52.03829787234042
#
# Record 116001-117000:
#
# Number of users registered in each year:
# 2012: 152
# 2013: 171
# 2014: 172
# 2015: 161
# 2016: 148
# 2017: 172
# 2018: 24
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,203.34
# Mean for number of unread messages for active females:
# 52.166666666666664
#
# Record 117001-118000:
#
# Number of users registered in each year:
# 2012: 173
# 2013: 170
# 2014: 143
# 2015: 173
# 2016: 155
# 2017: 166
# 2018: 20
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,282.54
# Mean for number of unread messages for active females:
# 47.17427385892116
#
# Record 118001-119000:
#
# Number of users registered in each year:
# 2012: 150
# 2013: 151
# 2014: 174
# 2015: 167
# 2016: 157
# 2017: 175
# 2018: 26
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,227.62
# Mean for number of unread messages for active females:
# 48.21132075471698
#
# Record 119001-120000:
#
# Number of users registered in each year:
# 2012: 178
# 2013: 160
# 2014: 149
# 2015: 176
# 2016: 153
# 2017: 171
# 2018: 13
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,297.62
# Mean for number of unread messages for active females:
# 47.2914979757085
#
# Record 120001-121000:
#
# Number of users registered in each year:
# 2012: 155
# 2013: 169
# 2014: 164
# 2015: 166
# 2016: 170
# 2017: 151
# 2018: 25
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,115.48
# Mean for number of unread messages for active females:
# 50.12444444444444
#
# Record 121001-122000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 154
# 2014: 164
# 2015: 154
# 2016: 157
# 2017: 177
# 2018: 27
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,294.13
# Mean for number of unread messages for active females:
# 51.93333333333333
#
# Record 122001-123000:
#
# Number of users registered in each year:
# 2012: 141
# 2013: 160
# 2014: 180
# 2015: 175
# 2016: 161
# 2017: 166
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,195.18
# Mean for number of unread messages for active females:
# 55.814655172413794
#
# Record 123001-124000:
#
# Number of users registered in each year:
# 2012: 141
# 2013: 162
# 2014: 179
# 2015: 165
# 2016: 167
# 2017: 152
# 2018: 34
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,123.57
# Mean for number of unread messages for active females:
# 49.95185185185185
#
# Record 124001-125000:
#
# Number of users registered in each year:
# 2012: 161
# 2013: 154
# 2014: 152
# 2015: 190
# 2016: 168
# 2017: 154
# 2018: 21
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,418.09
# Mean for number of unread messages for active females:
# 46.43933054393305
#
# Record 125001-126000:
#
# Number of users registered in each year:
# 2012: 155
# 2013: 176
# 2014: 150
# 2015: 160
# 2016: 189
# 2017: 145
# 2018: 25
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,010.13
# Mean for number of unread messages for active females:
# 51.68582375478927
#
# Record 126001-127000:
#
# Number of users registered in each year:
# 2012: 180
# 2013: 164
# 2014: 156
# 2015: 162
# 2016: 147
# 2017: 171
# 2018: 20
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,151.56
# Mean for number of unread messages for active females:
# 51.67782426778243
#
# Record 127001-128000:
#
# Number of users registered in each year:
# 2012: 156
# 2013: 171
# 2014: 178
# 2015: 181
# 2016: 142
# 2017: 148
# 2018: 24
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,166.60
# Mean for number of unread messages for active females:
# 50.403225806451616
#
# Record 128001-129000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 164
# 2014: 164
# 2015: 166
# 2016: 141
# 2017: 178
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,351.10
# Mean for number of unread messages for active females:
# 46.77777777777778
#
# Record 129001-130000:
#
# Number of users registered in each year:
# 2012: 158
# 2013: 154
# 2014: 158
# 2015: 168
# 2016: 169
# 2017: 167
# 2018: 26
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,324.05
# Mean for number of unread messages for active females:
# 53.878542510121456
#
# Record 130001-131000:
#
# Number of users registered in each year:
# 2012: 175
# 2013: 164
# 2014: 137
# 2015: 162
# 2016: 169
# 2017: 169
# 2018: 24
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,406.62
# Mean for number of unread messages for active females:
# 50.27165354330709
#
# Record 131001-132000:
#
# Number of users registered in each year:
# 2012: 187
# 2013: 166
# 2014: 155
# 2015: 166
# 2016: 149
# 2017: 151
# 2018: 26
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,293.24
# Mean for number of unread messages for active females:
# 51.36259541984733
#
# Record 132001-133000:
#
# Number of users registered in each year:
# 2012: 138
# 2013: 177
# 2014: 177
# 2015: 156
# 2016: 155
# 2017: 175
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,330.33
# Mean for number of unread messages for active females:
# 50.66822429906542
#
# Record 133001-134000:
#
# Number of users registered in each year:
# 2012: 169
# 2013: 156
# 2014: 155
# 2015: 167
# 2016: 157
# 2017: 175
# 2018: 21
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,365.44
# Mean for number of unread messages for active females:
# 45.85770750988142
#
# Record 134001-135000:
#
# Number of users registered in each year:
# 2012: 159
# 2013: 163
# 2014: 165
# 2015: 182
# 2016: 159
# 2017: 146
# 2018: 26
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,272.04
# Mean for number of unread messages for active females:
# 49.028112449799195
#
# Record 135001-136000:
#
# Number of users registered in each year:
# 2012: 156
# 2013: 164
# 2014: 148
# 2015: 190
# 2016: 164
# 2017: 149
# 2018: 29
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,267.44
# Mean for number of unread messages for active females:
# 50.34309623430963
#
# Record 136001-137000:
#
# Number of users registered in each year:
# 2012: 148
# 2013: 166
# 2014: 153
# 2015: 172
# 2016: 177
# 2017: 166
# 2018: 18
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,350.09
# Mean for number of unread messages for active females:
# 48.9
#
# Record 137001-138000:
#
# Number of users registered in each year:
# 2012: 161
# 2013: 170
# 2014: 159
# 2015: 162
# 2016: 170
# 2017: 160
# 2018: 18
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,233.90
# Mean for number of unread messages for active females:
# 49.77307692307692
#
# Record 138001-139000:
#
# Number of users registered in each year:
# 2012: 159
# 2013: 171
# 2014: 177
# 2015: 168
# 2016: 163
# 2017: 141
# 2018: 21
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,255.62
# Mean for number of unread messages for active females:
# 50.935064935064936
#
# Record 139001-140000:
#
# Number of users registered in each year:
# 2012: 182
# 2013: 154
# 2014: 167
# 2015: 162
# 2016: 151
# 2017: 167
# 2018: 17
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,210.35
# Mean for number of unread messages for active females:
# 48.30801687763713
# Record 140001-141000:
#
# Number of users registered in each year:
# 2012: 182
# 2013: 191
# 2014: 145
# 2015: 159
# 2016: 155
# 2017: 148
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,147.18
# Mean for number of unread messages for active females:
# 50.83739837398374
#
# Record 141001-142000:
#
# Number of users registered in each year:
# 2012: 149
# 2013: 177
# 2014: 169
# 2015: 175
# 2016: 154
# 2017: 156
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,314.23
# Mean for number of unread messages for active females:
# 52.95850622406639
#
# Record 142001-143000:
#
# Number of users registered in each year:
# 2012: 158
# 2013: 177
# 2014: 151
# 2015: 171
# 2016: 158
# 2017: 170
# 2018: 15
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,138.10
# Mean for number of unread messages for active females:
# 48.982078853046595
#
# Record 143001-144000:
#
# Number of users registered in each year:
# 2012: 160
# 2013: 160
# 2014: 155
# 2015: 157
# 2016: 180
# 2017: 160
# 2018: 28
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,265.70
# Mean for number of unread messages for active females:
# 48.024
#
# Record 144001-145000:
#
# Number of users registered in each year:
# 2012: 139
# 2013: 174
# 2014: 170
# 2015: 165
# 2016: 161
# 2017: 172
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,227.80
# Mean for number of unread messages for active females:
# 48.98814229249012
#
# Record 145001-146000:
#
# Number of users registered in each year:
# 2012: 140
# 2013: 171
# 2014: 159
# 2015: 162
# 2016: 180
# 2017: 162
# 2018: 26
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,401.84
# Mean for number of unread messages for active females:
# 53.71212121212121
#
# Record 146001-147000:
#
# Number of users registered in each year:
# 2012: 145
# 2013: 161
# 2014: 169
# 2015: 157
# 2016: 177
# 2017: 169
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,231.05
# Mean for number of unread messages for active females:
# 48.764940239043824
#
# Record 147001-148000:
#
# Number of users registered in each year:
# 2012: 181
# 2013: 155
# 2014: 147
# 2015: 168
# 2016: 178
# 2017: 149
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,295.49
# Mean for number of unread messages for active females:
# 47.79916317991632
#
# Record 148001-149000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 175
# 2014: 143
# 2015: 177
# 2016: 168
# 2017: 146
# 2018: 23
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,244.86
# Mean for number of unread messages for active females:
# 50.488461538461536
#
# Record 149001-150000:
#
# Number of users registered in each year:
# 2012: 160
# 2013: 180
# 2014: 163
# 2015: 154
# 2016: 150
# 2017: 173
# 2018: 20
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,194.65
# Mean for number of unread messages for active females:
# 46.59649122807018
#
# Record 150001-151000:
#
# Number of users registered in each year:
# 2012: 169
# 2013: 180
# 2014: 163
# 2015: 166
# 2016: 166
# 2017: 137
# 2018: 19
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,239.35
# Mean for number of unread messages for active females:
# 48.71666666666667
#
# Record 151001-152000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 191
# 2014: 149
# 2015: 152
# 2016: 148
# 2017: 170
# 2018: 23
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,277.26
# Mean for number of unread messages for active females:
# 48.20238095238095
#
# Record 152001-153000:
#
# Number of users registered in each year:
# 2012: 183
# 2013: 159
# 2014: 160
# 2015: 155
# 2016: 156
# 2017: 164
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,143.61
# Mean for number of unread messages for active females:
# 49.90196078431372
#
# Record 153001-154000:
#
# Number of users registered in each year:
# 2012: 158
# 2013: 159
# 2014: 164
# 2015: 167
# 2016: 164
# 2017: 162
# 2018: 26
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,107.58
# Mean for number of unread messages for active females:
# 51.92217898832685
#
# Record 154001-155000:
#
# Number of users registered in each year:
# 2012: 191
# 2013: 181
# 2014: 158
# 2015: 137
# 2016: 157
# 2017: 155
# 2018: 21
# Median for number of friends:
# 5.0
# Median age for users:
# 34.5
# Mean balance amount:
# $5,232.04
# Mean for number of unread messages for active females:
# 47.18725099601593
#
# Record 155001-156000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 165
# 2014: 166
# 2015: 153
# 2016: 160
# 2017: 169
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,314.75
# Mean for number of unread messages for active females:
# 54.77916666666667
#
# Record 156001-157000:
#
# Number of users registered in each year:
# 2012: 156
# 2013: 162
# 2014: 159
# 2015: 171
# 2016: 186
# 2017: 140
# 2018: 26
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,221.77
# Mean for number of unread messages for active females:
# 49.80487804878049
#
# Record 157001-158000:
#
# Number of users registered in each year:
# 2012: 151
# 2013: 174
# 2014: 153
# 2015: 163
# 2016: 146
# 2017: 182
# 2018: 31
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,239.48
# Mean for number of unread messages for active females:
# 49.37051792828685
#
# Record 158001-159000:
#
# Number of users registered in each year:
# 2012: 150
# 2013: 152
# 2014: 170
# 2015: 197
# 2016: 145
# 2017: 164
# 2018: 22
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,227.55
# Mean for number of unread messages for active females:
# 50.2972972972973
#
# Record 159001-160000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 179
# 2014: 165
# 2015: 163
# 2016: 148
# 2017: 172
# 2018: 16
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,251.74
# Mean for number of unread messages for active females:
# 48.770212765957446
#
# Record 160001-161000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 143
# 2014: 139
# 2015: 178
# 2016: 195
# 2017: 158
# 2018: 20
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,190.97
# Mean for number of unread messages for active females:
# 48.93675889328063
#
# Record 161001-162000:
#
# Number of users registered in each year:
# 2012: 180
# 2013: 156
# 2014: 160
# 2015: 156
# 2016: 167
# 2017: 156
# 2018: 25
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,317.70
# Mean for number of unread messages for active females:
# 50.519823788546255
#
# Record 162001-163000:
#
# Number of users registered in each year:
# 2012: 184
# 2013: 180
# 2014: 131
# 2015: 157
# 2016: 176
# 2017: 153
# 2018: 19
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,239.01
# Mean for number of unread messages for active females:
# 51.696
#
# Record 163001-164000:
#
# Number of users registered in each year:
# 2012: 176
# 2013: 141
# 2014: 167
# 2015: 169
# 2016: 181
# 2017: 146
# 2018: 20
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,126.82
# Mean for number of unread messages for active females:
# 50.355731225296445
#
# Record 164001-165000:
#
# Number of users registered in each year:
# 2012: 174
# 2013: 168
# 2014: 169
# 2015: 163
# 2016: 166
# 2017: 143
# 2018: 17
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,160.22
# Mean for number of unread messages for active females:
# 51.954372623574145
#
# Record 165001-166000:
#
# Number of users registered in each year:
# 2012: 152
# 2013: 160
# 2014: 179
# 2015: 178
# 2016: 155
# 2017: 163
# 2018: 13
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,230.19
# Mean for number of unread messages for active females:
# 47.44396551724138
#
# Record 166001-167000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 170
# 2014: 166
# 2015: 153
# 2016: 175
# 2017: 165
# 2018: 14
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,298.42
# Mean for number of unread messages for active females:
# 48.73360655737705
#
# Record 167001-168000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 156
# 2014: 173
# 2015: 151
# 2016: 162
# 2017: 163
# 2018: 29
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,399.41
# Mean for number of unread messages for active females:
# 48.57707509881423
# Record 168001-169000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 171
# 2014: 154
# 2015: 161
# 2016: 171
# 2017: 158
# 2018: 15
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,249.74
# Mean for number of unread messages for active females:
# 50.27235772357724
#
# Record 169001-170000:
#
# Number of users registered in each year:
# 2012: 167
# 2013: 155
# 2014: 149
# 2015: 157
# 2016: 168
# 2017: 180
# 2018: 24
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,460.35
# Mean for number of unread messages for active females:
# 49.86206896551724
#
# Record 170001-171000:
#
# Number of users registered in each year:
# 2012: 153
# 2013: 168
# 2014: 142
# 2015: 158
# 2016: 187
# 2017: 176
# 2018: 16
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,203.71
# Mean for number of unread messages for active females:
# 52.388663967611336
#
# Record 171001-172000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 178
# 2014: 168
# 2015: 150
# 2016: 169
# 2017: 145
# 2018: 22
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,460.46
# Mean for number of unread messages for active females:
# 47.11153846153846
#
# Record 172001-173000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 174
# 2014: 149
# 2015: 149
# 2016: 174
# 2017: 167
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,364.17
# Mean for number of unread messages for active females:
# 47.98884758364312
#
# Record 173001-174000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 146
# 2014: 182
# 2015: 161
# 2016: 163
# 2017: 162
# 2018: 20
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,274.93
# Mean for number of unread messages for active females:
# 49.43396226415094
#
# Record 174001-175000:
#
# Number of users registered in each year:
# 2012: 174
# 2013: 151
# 2014: 166
# 2015: 175
# 2016: 164
# 2017: 145
# 2018: 25
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,137.46
# Mean for number of unread messages for active females:
# 49.51119402985075
#
# Record 175001-176000:
#
# Number of users registered in each year:
# 2012: 148
# 2013: 155
# 2014: 173
# 2015: 163
# 2016: 172
# 2017: 168
# 2018: 21
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,091.05
# Mean for number of unread messages for active females:
# 50.74418604651163
#
# Record 176001-177000:
#
# Number of users registered in each year:
# 2012: 153
# 2013: 146
# 2014: 169
# 2015: 165
# 2016: 175
# 2017: 167
# 2018: 25
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,295.41
# Mean for number of unread messages for active females:
# 50.57142857142857
#
# Record 177001-178000:
#
# Number of users registered in each year:
# 2012: 168
# 2013: 176
# 2014: 138
# 2015: 156
# 2016: 170
# 2017: 166
# 2018: 26
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,371.17
# Mean for number of unread messages for active females:
# 48.689516129032256
#
# Record 178001-179000:
#
# Number of users registered in each year:
# 2012: 173
# 2013: 161
# 2014: 171
# 2015: 144
# 2016: 145
# 2017: 182
# 2018: 24
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,253.04
# Mean for number of unread messages for active females:
# 49.515625
#
# Record 179001-180000:
#
# Number of users registered in each year:
# 2012: 138
# 2013: 163
# 2014: 167
# 2015: 171
# 2016: 165
# 2017: 179
# 2018: 17
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,126.36
# Mean for number of unread messages for active females:
# 52.615094339622644
#
# Record 180001-181000:
#
# Number of users registered in each year:
# 2012: 161
# 2013: 165
# 2014: 168
# 2015: 143
# 2016: 167
# 2017: 169
# 2018: 27
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,251.47
# Mean for number of unread messages for active females:
# 49.226765799256505
#
# Record 181001-182000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 184
# 2014: 152
# 2015: 159
# 2016: 153
# 2017: 170
# 2018: 25
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,258.58
# Mean for number of unread messages for active females:
# 52.38996138996139
#
# Record 182001-183000:
#
# Number of users registered in each year:
# 2012: 143
# 2013: 152
# 2014: 186
# 2015: 144
# 2016: 181
# 2017: 169
# 2018: 25
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,307.42
# Mean for number of unread messages for active females:
# 50.83399209486166
#
# Record 183001-184000:
#
# Number of users registered in each year:
# 2012: 170
# 2013: 170
# 2014: 156
# 2015: 167
# 2016: 158
# 2017: 160
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,147.75
# Mean for number of unread messages for active females:
# 52.6875
#
# Record 184001-185000:
#
# Number of users registered in each year:
# 2012: 176
# 2013: 154
# 2014: 168
# 2015: 178
# 2016: 149
# 2017: 148
# 2018: 27
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,333.19
# Mean for number of unread messages for active females:
# 54.89878542510122
#
# Record 185001-186000:
#
# Number of users registered in each year:
# 2012: 166
# 2013: 177
# 2014: 174
# 2015: 163
# 2016: 146
# 2017: 151
# 2018: 23
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,291.28
# Mean for number of unread messages for active females:
# 47.752066115702476
#
# Record 186001-187000:
#
# Number of users registered in each year:
# 2012: 175
# 2013: 143
# 2014: 161
# 2015: 165
# 2016: 181
# 2017: 146
# 2018: 29
# Median for number of friends:
# 5.5
# Median age for users:
# 34.0
# Mean balance amount:
# $5,338.81
# Mean for number of unread messages for active females:
# 50.70992366412214
#
# Record 187001-188000:
#
# Number of users registered in each year:
# 2012: 161
# 2013: 160
# 2014: 159
# 2015: 154
# 2016: 164
# 2017: 181
# 2018: 21
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,164.61
# Mean for number of unread messages for active females:
# 51.00409836065574
#
# Record 188001-189000:
#
# Number of users registered in each year:
# 2012: 154
# 2013: 155
# 2014: 168
# 2015: 165
# 2016: 169
# 2017: 172
# 2018: 17
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,340.28
# Mean for number of unread messages for active females:
# 50.7956204379562
#
# Record 189001-190000:
#
# Number of users registered in each year:
# 2012: 177
# 2013: 152
# 2014: 188
# 2015: 141
# 2016: 169
# 2017: 148
# 2018: 25
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,319.51
# Mean for number of unread messages for active females:
# 51.48979591836735
#
# Record 190001-191000:
#
# Number of users registered in each year:
# 2012: 164
# 2013: 167
# 2014: 177
# 2015: 136
# 2016: 154
# 2017: 184
# 2018: 18
# Median for number of friends:
# 5.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,278.23
# Mean for number of unread messages for active females:
# 47.99209486166008
#
# Record 191001-192000:
#
# Number of users registered in each year:
# 2012: 163
# 2013: 152
# 2014: 179
# 2015: 160
# 2016: 169
# 2017: 147
# 2018: 30
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,388.19
# Mean for number of unread messages for active females:
# 50.1063829787234
#
# Record 192001-193000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 151
# 2014: 162
# 2015: 171
# 2016: 181
# 2017: 161
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,460.34
# Mean for number of unread messages for active females:
# 49.250936329588015
#
# Record 193001-194000:
#
# Number of users registered in each year:
# 2012: 155
# 2013: 147
# 2014: 176
# 2015: 164
# 2016: 171
# 2017: 163
# 2018: 24
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,376.62
# Mean for number of unread messages for active females:
# 51.170212765957444
#
# Record 194001-195000:
#
# Number of users registered in each year:
# 2012: 169
# 2013: 163
# 2014: 152
# 2015: 172
# 2016: 155
# 2017: 168
# 2018: 21
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,102.79
# Mean for number of unread messages for active females:
# 50.454887218045116
#
# Record 195001-196000:
#
# Number of users registered in each year:
# 2012: 134
# 2013: 150
# 2014: 180
# 2015: 175
# 2016: 167
# 2017: 175
# 2018: 19
# Median for number of friends:
# 6.0
# Median age for users:
# 34.0
# Mean balance amount:
# $5,211.26
# Mean for number of unread messages for active females:
# 50.041825095057035
# Record 196001-197000:
#
# Number of users registered in each year:
# 2012: 164
# 2013: 158
# 2014: 164
# 2015: 173
# 2016: 144
# 2017: 173
# 2018: 24
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,148.03
# Mean for number of unread messages for active females:
# 50.253787878787875
#
# Record 197001-198000:
#
# Number of users registered in each year:
# 2012: 157
# 2013: 161
# 2014: 181
# 2015: 165
# 2016: 158
# 2017: 161
# 2018: 17
# Median for number of friends:
# 5.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,242.04
# Mean for number of unread messages for active females:
# 47.95378151260504
#
# Record 198001-199000:
#
# Number of users registered in each year:
# 2012: 152
# 2013: 176
# 2014: 162
# 2015: 177
# 2016: 155
# 2017: 157
# 2018: 21
# Median for number of friends:
# 6.0
# Median age for users:
# 35.0
# Mean balance amount:
# $5,347.38
# Mean for number of unread messages for active females:
# 47.376
#
# Record 199001-200000:
#
# Number of users registered in each year:
# 2012: 160
# 2013: 171
# 2014: 145
# 2015: 156
# 2016: 186
# 2017: 158
# 2018: 24
# Median for number of friends:
# 6.0
# Median age for users:
# 36.0
# Mean balance amount:
# $5,280.53
# Mean for number of unread messages for active females:
# 49.68888888888889
